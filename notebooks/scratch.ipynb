# %% [markdown]
# ### Testing notebook:

# %%
import numpy as np
from distance import cos_similarity
from vector_search import Naive

vector = np.random.rand(1000, 128)

# %%
# %%timeit
store = [vector]
for vec in vector:
    store.append(vec)
# Out:
# 66.7 μs ± 516 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
store = vector
store = np.vstack((store, vector))
# Out:
# 96.8 μs ± 3.09 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
if store.any():
    store = np.vstack((store, vector))

# %%
store.shape
# Out:
# (11000, 128)

# %%
np.stack(store, vector, axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 np.stack(store, vector, axis=0)
#
# TypeError: stack() got multiple values for argument 'axis'

# %%
store.shape
# Out:
# (10000, 128)

# %%
rand_arr = np.random.rand(1000, 128)

# %%
naive = Naive(dimension=128)

# %%
naive.store = [rand_arr[i] for i in range(1000)]

# %%
naive.search(query_vector=rand_arr[0], k=5)
# Out:
# [(np.float64(1.0),
#   array([0.97793826, 0.46301172, 0.87564004, 0.99744987, 0.91614147,
#          0.97252564, 0.06685616, 0.22047275, 0.47524102, 0.52444001,
#          0.55492256, 0.03207311, 0.68031835, 0.31794821, 0.02218075,
#          0.63436   , 0.28980336, 0.37607344, 0.21842248, 0.82086481,
#          0.07566392, 0.00739093, 0.64550577, 0.79717208, 0.70029565,
#          0.99849808, 0.613888  , 0.37201584, 0.96298705, 0.16246218,
#          0.25556709, 0.38396322, 0.7276742 , 0.59453949, 0.80901428,
#          0.17045897, 0.26219297, 0.57166735, 0.1294702 , 0.78812706,
#          0.00131219, 0.75044103, 0.17866777, 0.55041841, 0.73947052,
#          0.88959502, 0.46198986, 0.52669145, 0.06950851, 0.15345903,
#          0.66282621, 0.00845123, 0.22450798, 0.56005276, 0.21921578,
#          0.98555835, 0.74919821, 0.33730097, 0.98584153, 0.87887074,
#          0.12756596, 0.760293  , 0.06700672, 0.69229397, 0.53111423,
# ...
